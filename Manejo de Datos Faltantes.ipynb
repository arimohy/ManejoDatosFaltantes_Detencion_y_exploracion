# %% [markdown]
# # Manejo de Datos Faltantes: Detección y Exploración

# %%
#pip install -r requirements.txt

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import session_info

import janitor
import missingno
import pyreadr
import upsetplot

# %% [markdown]
# ## Cargar los datos

# %%
pima_indians_diabetes_url="https://raw.githubusercontent.com/npradaschnor/Pima-Indians-Diabetes-Dataset/master/diabetes.csv"
diabetes_df = pd.read_csv(pima_indians_diabetes_url,sep=',')

# %%
base_url = "https://github.com/njtierney/naniar/raw/master/data/"
datasets_names = ("oceanbuoys", "pedestrian", "riskfactors")
extension = ".rda"

# %%
import urllib.request

datasets_dfs = {}

for dataset_name in datasets_names:

    dataset_file = f"{ dataset_name }{ extension }"
    dataset_output_file = f"./data/{ dataset_file }"
    dataset_url = f"{ base_url }{ dataset_file }"
    
    urllib.request.urlretrieve(dataset_url, dataset_output_file)

    datasets_dfs[f"{ dataset_name }_df"] = pyreadr.read_r(dataset_output_file).get(dataset_name)

datasets_dfs.keys()
# Out:
# dict_keys(['oceanbuoys_df', 'pedestrian_df', 'riskfactors_df'])

# %%
locals().update(**datasets_dfs)
del datasets_dfs

# %% [markdown]
# ### Verificar la Carga de datos

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ### Importando pandas

# %%
import pandas as pd

# %%
# %run pandas-missing-extension.ipynb

# %%
diabetes_df.missing.missing_variable_summary()
# Out:
#                    variable  n_missing  n_cases  pct_missing
# 0               Pregnancies          0      768          0.0
# 1                   Glucose          0      768          0.0
# 2             BloodPressure          0      768          0.0
# 3             SkinThickness          0      768          0.0
# 4                   Insulin          0      768          0.0
# 5                       BMI          0      768          0.0
# 6  DiabetesPedigreeFunction          0      768          0.0
# 7                       Age          0      768          0.0
# 8                   Outcome          0      768          0.0

# %%
riskfactors_df.missing.missing_variable_summary()
# Out:
#             variable  n_missing  n_cases  pct_missing
# 0              state          0      245     0.000000
# 1                sex          0      245     0.000000
# 2                age          0      245     0.000000
# 3         weight_lbs         10      245     4.081633
# 4        height_inch          2      245     0.816327
# 5                bmi         11      245     4.489796
# 6            marital          1      245     0.408163
# 7           pregnant        215      245    87.755102
# 8           children          0      245     0.000000
# 9          education          1      245     0.408163
# 10        employment          0      245     0.000000
# 11            income          0      245     0.000000
# 12           veteran          3      245     1.224490
# 13          hispanic          2      245     0.816327
# 14    health_general          0      245     0.000000
# 15   health_physical          0      245     0.000000
# 16     health_mental          0      245     0.000000
# 17       health_poor        113      245    46.122449
# 18      health_cover          0      245     0.000000
# 19      provide_care          3      245     1.224490
# 20  activity_limited          3      245     1.224490
# 21         drink_any          2      245     0.816327
# 22        drink_days        134      245    54.693878
# 23     drink_average        135      245    55.102041
# 24         smoke_100          2      245     0.816327
# 25        smoke_days        128      245    52.244898
# 26        smoke_stop        212      245    86.530612
# 27        smoke_last        161      245    65.714286
# 28        diet_fruit          8      245     3.265306
# 29        diet_salad          8      245     3.265306
# 30       diet_potato          8      245     3.265306
# 31       diet_carrot          8      245     3.265306
# 32    diet_vegetable          8      245     3.265306
# 33        diet_juice          8      245     3.265306

# %%
riskfactors_df.missing.missing_variable_table()
# Out:
#     n_missing_in_variable  n_variables  pct_variables
# 0                       0           10      29.411765
# 1                       8            6      17.647059
# 2                       2            4      11.764706
# 3                       3            3       8.823529
# 4                       1            2       5.882353
# 5                      10            1       2.941176
# 6                      11            1       2.941176
# 7                     113            1       2.941176
# 8                     128            1       2.941176
# 9                     134            1       2.941176
# 10                    135            1       2.941176
# 11                    161            1       2.941176
# 12                    212            1       2.941176
# 13                    215            1       2.941176

# %%
riskfactors_df.missing.missing_case_summary()
# Out:
#      case  n_missing  pct_missing
# 0       0          6    16.666667
# 1       1          6    16.666667
# 2       2          7    19.444444
# 3       3         12    33.333333
# 4       4          5    13.888889
# ..    ...        ...          ...
# 240   240          6    16.666667
# 241   241          5    13.888889
# 242   242          3     8.333333
# 243   243          2     5.555556
# 244   244          3     8.333333
#
# [245 rows x 3 columns]

# %%
riskfactors_df.missing.missing_case_table()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19844\3493182342.py in ?()
# ----> 1 riskfactors_df.missing.missing_case_table()
#
# ~\AppData\Local\Temp\ipykernel_19844\2822139721.py in ?(self)
#      48             self._obj.missing.missing_case_summary()
#      49             .value_counts("n_missing")
#      50             .reset_index()
#      51             .rename(columns={"n_missing": "n_missing_in_case", 0: "n_cases"})
# ---> 52             .assign(pct_case=lambda df: df.n_cases / df.n_cases.sum() * 100)
#      53             .sort_values("pct_case", ascending=False)
#      54         )
#
# c:\Users\Pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, **kwargs)
#    5235         """
#    5236         data = self.copy(deep=None)
#    5237
#    5238         for k, v in kwargs.items():
# -> 5239             data[k] = com.apply_if_callable(v, data)
#    5240         return data
#
# c:\Users\Pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\common.py in ?(maybe_callable, obj, **kwargs)
#     380     obj : NDFrame
#     381     **kwargs
#     382     """
#     383     if callable(maybe_callable):
# --> 384         return maybe_callable(obj, **kwargs)
#     385
#     386     return maybe_callable
#
# ~\AppData\Local\Temp\ipykernel_19844\2822139721.py in ?(df)
# ---> 52             .assign(pct_case=lambda df: df.n_cases / df.n_cases.sum() * 100)
#
# c:\Users\Pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'n_cases'
